# %%
from collections import deque
import gym
import matplotlib.pyplot as plt
from IPython import display
import time
import torch
import torch.nn as nn
import numpy as np
import random

# %%
env = gym.make("Acrobot-v1")
state = env.reset()
state_size = env.observation_space.shape[0]
action_size = env.action_space.n
batch_size = 64
epochs = 1000
device = 'cuda' if torch.cuda.is_available() else 'cpu'

# %%
class NNet(nn.Module):
    def __init__(self):
        super(NNet,self).__init__()
        self.lin1 = nn.Linear(state_size,16)
        self.lin2 = nn.Linear(16,32)
        self.lin3 = nn.Linear(32,action_size)
        self.relu = nn.ReLU()

    def forward(self,x):
#         pred = torch.from_numpy(x.reshape(1,state_size)).float().to(device)
        pred = self.lin1(x)
        pred = self.relu(pred)
        pred = self.lin2(pred)
        pred = self.relu(pred)
        pred = self.lin3(pred)

        return pred

# %%
class dqn_agent():
    def __init__(self,state_size,action_size):
        self.state_size = state_size
        self.action_size = action_size
        self.memory = deque(maxlen=2000)
        self.gamma = 0.95
        self.epsilon = 1
        self.epsilon_rate = 0.995
        self.epsilon_lim = 0.01
        self.lr = 0.001
        self.model = NNet().to(device)
        self.target_model = NNet().to(device)
        self.criterion = nn.MSELoss()
        self.optim = torch.optim.Adam(self.model.parameters(),lr=self.lr)
    def train(self,batch_size):
        batch = random.sample(self.memory,batch_size)
        self.target_model.load_state_dict(self.model.state_dict())
        for state,action,reward,next_state,done in batch:
            state = torch.from_numpy(state.reshape(1,state_size)).float().to(device)
            next_state = torch.from_numpy(next_state.reshape(1,state_size)).float().to(device)
            pred = self.model(state)[0][action]
            target = torch.tensor(reward,dtype=torch.float32).to(device)
            if not done:
                action_index = torch.argmax(self.model(next_state)[0])
                target = target+self.target_model(next_state)[0][action_index]
            loss = self.criterion(pred,target.to(device))
            loss.backward()
            self.optim.step()
            self.optim.zero_grad()
        if self.epsilon>self.epsilon_lim:
            self.epsilon*=self.epsilon_rate
    def action(self,state):
        if np.random.rand()<=self.epsilon:
            return torch.tensor(random.randrange(self.action_size))
        else:
            state = torch.from_numpy(state.reshape(1,state_size)).float().to(device)
            return torch.argmax(self.model(state)[0])
    def remember(self,state,action,reward,next_state,done):
        self.memory.append((state,action,reward,next_state,done))

# %%
agent = dqn_agent(state_size,action_size)

for epoch in range(epochs):
    state = env.reset()
    
    done = False
    times = 0
    while not done:
        action = agent.action(state)
        if epoch%20 == 0:
            env.render()
        next_state, reward, done, info = env.step(action.to('cpu').numpy())
        if done:
            if reward==0:
                reward = 3000
            else:
                reward =-3000
        else:
            reward = -5+abs(next_state[4])
                
        agent.remember(state,action,reward,next_state,done)
        state = next_state
        if done:
            print(f'epoch = {epoch}/{epochs}, score = {times}, epsilon = {agent.epsilon:.4f}')
        times+=1
        if not done and len(agent.memory)>=batch_size and times%32==0:
            agent.train(batch_size)
    if epoch%20 == 0:
        env.close()
    if times <= 90:
        break
# Out:
# epoch = 0/1000, score = 499, epsilon = 0.9322
# epoch = 1/1000, score = 499, epsilon = 0.8647
# epoch = 2/1000, score = 499, epsilon = 0.8021
# epoch = 3/1000, score = 499, epsilon = 0.7440
# epoch = 4/1000, score = 499, epsilon = 0.6901
# epoch = 5/1000, score = 499, epsilon = 0.6401
# epoch = 6/1000, score = 499, epsilon = 0.5937
# epoch = 7/1000, score = 459, epsilon = 0.5535
# epoch = 8/1000, score = 499, epsilon = 0.5134
# epoch = 9/1000, score = 499, epsilon = 0.4762
# epoch = 10/1000, score = 499, epsilon = 0.4417
# epoch = 11/1000, score = 499, epsilon = 0.4097
# epoch = 12/1000, score = 499, epsilon = 0.3801
# epoch = 13/1000, score = 499, epsilon = 0.3525
# epoch = 14/1000, score = 499, epsilon = 0.3270
# epoch = 15/1000, score = 499, epsilon = 0.3033
# epoch = 16/1000, score = 499, epsilon = 0.2813
# epoch = 17/1000, score = 499, epsilon = 0.2610
# epoch = 18/1000, score = 499, epsilon = 0.2421
# epoch = 19/1000, score = 499, epsilon = 0.2245
# epoch = 20/1000, score = 499, epsilon = 0.2083
# epoch = 21/1000, score = 499, epsilon = 0.1932
# epoch = 22/1000, score = 499, epsilon = 0.1792
# epoch = 23/1000, score = 499, epsilon = 0.1662
# epoch = 24/1000, score = 499, epsilon = 0.1542
# epoch = 25/1000, score = 499, epsilon = 0.1430
# epoch = 26/1000, score = 265, epsilon = 0.1374
# epoch = 27/1000, score = 499, epsilon = 0.1274
# epoch = 28/1000, score = 499, epsilon = 0.1182
# epoch = 29/1000, score = 499, epsilon = 0.1096
# epoch = 30/1000, score = 499, epsilon = 0.1017
# epoch = 31/1000, score = 499, epsilon = 0.0943
# epoch = 32/1000, score = 342, epsilon = 0.0897
# epoch = 33/1000, score = 486, epsilon = 0.0832
# epoch = 34/1000, score = 399, epsilon = 0.0784
# epoch = 35/1000, score = 360, epsilon = 0.0742
# epoch = 36/1000, score = 499, epsilon = 0.0688
# epoch = 37/1000, score = 386, epsilon = 0.0648
# epoch = 38/1000, score = 321, epsilon = 0.0616
# epoch = 39/1000, score = 466, epsilon = 0.0574
# epoch = 40/1000, score = 224, epsilon = 0.0555
# epoch = 41/1000, score = 499, epsilon = 0.0514
# epoch = 42/1000, score = 449, epsilon = 0.0479
# epoch = 43/1000, score = 232, epsilon = 0.0463
# epoch = 44/1000, score = 376, epsilon = 0.0438
# epoch = 45/1000, score = 499, epsilon = 0.0406
# epoch = 46/1000, score = 188, epsilon = 0.0396
# epoch = 47/1000, score = 391, epsilon = 0.0373
# epoch = 48/1000, score = 455, epsilon = 0.0348
# epoch = 49/1000, score = 470, epsilon = 0.0324
# epoch = 50/1000, score = 232, epsilon = 0.0313
# epoch = 51/1000, score = 499, epsilon = 0.0290
# epoch = 52/1000, score = 499, epsilon = 0.0269
# epoch = 53/1000, score = 499, epsilon = 0.0250
# epoch = 54/1000, score = 338, epsilon = 0.0238
# epoch = 55/1000, score = 499, epsilon = 0.0220
# epoch = 56/1000, score = 492, epsilon = 0.0205
# epoch = 57/1000, score = 499, epsilon = 0.0190
# epoch = 58/1000, score = 404, epsilon = 0.0179
# epoch = 59/1000, score = 499, epsilon = 0.0166
# epoch = 60/1000, score = 297, epsilon = 0.0158
# epoch = 61/1000, score = 496, epsilon = 0.0147
# epoch = 62/1000, score = 499, epsilon = 0.0136
# epoch = 63/1000, score = 499, epsilon = 0.0126
# epoch = 64/1000, score = 437, epsilon = 0.0118
# epoch = 65/1000, score = 499, epsilon = 0.0110
# epoch = 66/1000, score = 499, epsilon = 0.0102
# epoch = 67/1000, score = 499, epsilon = 0.0100
# epoch = 68/1000, score = 499, epsilon = 0.0100
# epoch = 69/1000, score = 383, epsilon = 0.0100
# epoch = 70/1000, score = 404, epsilon = 0.0100
# epoch = 71/1000, score = 258, epsilon = 0.0100
# epoch = 72/1000, score = 414, epsilon = 0.0100
# epoch = 73/1000, score = 499, epsilon = 0.0100
# epoch = 74/1000, score = 499, epsilon = 0.0100
# epoch = 75/1000, score = 172, epsilon = 0.0100
# epoch = 76/1000, score = 367, epsilon = 0.0100
# epoch = 77/1000, score = 281, epsilon = 0.0100
# epoch = 78/1000, score = 167, epsilon = 0.0100
# epoch = 79/1000, score = 498, epsilon = 0.0100
# epoch = 80/1000, score = 256, epsilon = 0.0100
# epoch = 81/1000, score = 174, epsilon = 0.0100
# epoch = 82/1000, score = 499, epsilon = 0.0100
# epoch = 83/1000, score = 296, epsilon = 0.0100
# epoch = 84/1000, score = 132, epsilon = 0.0100
# epoch = 85/1000, score = 128, epsilon = 0.0100
# epoch = 86/1000, score = 404, epsilon = 0.0100
# epoch = 87/1000, score = 380, epsilon = 0.0100
# epoch = 88/1000, score = 357, epsilon = 0.0100
# epoch = 89/1000, score = 171, epsilon = 0.0100
# epoch = 90/1000, score = 328, epsilon = 0.0100
# epoch = 91/1000, score = 257, epsilon = 0.0100
# epoch = 92/1000, score = 487, epsilon = 0.0100
# epoch = 93/1000, score = 156, epsilon = 0.0100
# epoch = 94/1000, score = 178, epsilon = 0.0100
# epoch = 95/1000, score = 144, epsilon = 0.0100
# epoch = 96/1000, score = 116, epsilon = 0.0100
# epoch = 97/1000, score = 289, epsilon = 0.0100
# epoch = 98/1000, score = 178, epsilon = 0.0100
# epoch = 99/1000, score = 135, epsilon = 0.0100
# epoch = 100/1000, score = 113, epsilon = 0.0100
# epoch = 101/1000, score = 146, epsilon = 0.0100
# epoch = 102/1000, score = 137, epsilon = 0.0100
# epoch = 103/1000, score = 116, epsilon = 0.0100
# epoch = 104/1000, score = 128, epsilon = 0.0100
# epoch = 105/1000, score = 254, epsilon = 0.0100
# epoch = 106/1000, score = 123, epsilon = 0.0100
# epoch = 107/1000, score = 107, epsilon = 0.0100
# epoch = 108/1000, score = 116, epsilon = 0.0100
# epoch = 109/1000, score = 82, epsilon = 0.0100

# %%
# play test:
for epoch in range(100):
    state = env.reset()   
    done = False
    times = 0
    while not done:
        action = agent.action(state)
        env.render()
        next_state, reward, done, info = env.step(action.to('cpu').numpy())
        state = next_state
        if done:
            print(f'episode = {epoch}/{100}, score = {times}')
        times+=1
    env.close()
# Out:
# episode = 0/100, score = 141
# episode = 1/100, score = 112
# episode = 2/100, score = 92
# episode = 3/100, score = 85
# episode = 4/100, score = 92
# episode = 5/100, score = 102
# episode = 6/100, score = 91
# episode = 7/100, score = 91
# episode = 8/100, score = 91
# episode = 9/100, score = 124
# episode = 10/100, score = 114
# episode = 11/100, score = 91
# episode = 12/100, score = 98
# episode = 13/100, score = 95
# episode = 14/100, score = 101
# episode = 15/100, score = 102
# episode = 16/100, score = 141
# episode = 17/100, score = 118
# episode = 18/100, score = 91
# episode = 19/100, score = 101
# episode = 20/100, score = 232
# episode = 21/100, score = 93
# episode = 22/100, score = 90
# episode = 23/100, score = 91
# episode = 24/100, score = 110
# episode = 25/100, score = 133
# episode = 26/100, score = 105
# episode = 27/100, score = 97
# episode = 28/100, score = 91
# episode = 29/100, score = 174
# episode = 30/100, score = 109
# episode = 31/100, score = 101
# episode = 32/100, score = 101
# episode = 33/100, score = 89
# episode = 34/100, score = 231
# episode = 35/100, score = 106
# episode = 36/100, score = 82
# episode = 37/100, score = 89
# episode = 38/100, score = 107
# episode = 39/100, score = 91
# episode = 40/100, score = 170
# episode = 41/100, score = 114
# episode = 42/100, score = 103
# episode = 43/100, score = 104
# episode = 44/100, score = 93
# episode = 45/100, score = 103
# episode = 46/100, score = 109
# episode = 47/100, score = 107
# episode = 48/100, score = 96
# episode = 49/100, score = 93
# episode = 50/100, score = 107
# episode = 51/100, score = 103
# episode = 52/100, score = 157
# episode = 53/100, score = 94
# episode = 54/100, score = 83
# episode = 55/100, score = 112
# episode = 56/100, score = 103
# episode = 57/100, score = 89
# episode = 58/100, score = 117
# episode = 59/100, score = 148
# episode = 60/100, score = 121
# episode = 61/100, score = 91
# episode = 62/100, score = 93
# episode = 63/100, score = 102
# episode = 64/100, score = 90
# episode = 65/100, score = 107
# episode = 66/100, score = 91
# episode = 67/100, score = 89
# episode = 68/100, score = 83
# episode = 69/100, score = 107
# episode = 70/100, score = 97
# episode = 71/100, score = 102
# episode = 72/100, score = 102
# episode = 73/100, score = 106
# episode = 74/100, score = 95
# episode = 75/100, score = 105
# episode = 76/100, score = 98
# episode = 77/100, score = 95
# episode = 78/100, score = 133
# episode = 79/100, score = 108
# episode = 80/100, score = 140
# episode = 81/100, score = 102
# episode = 82/100, score = 91
# episode = 83/100, score = 93
# episode = 84/100, score = 110
# episode = 85/100, score = 114
# episode = 86/100, score = 91
# episode = 87/100, score = 105
# episode = 88/100, score = 112
# episode = 89/100, score = 152
# episode = 90/100, score = 98
# episode = 91/100, score = 91
# episode = 92/100, score = 110
# episode = 93/100, score = 126
# episode = 94/100, score = 93
# episode = 95/100, score = 90
# episode = 96/100, score = 88
# episode = 97/100, score = 148
# episode = 98/100, score = 195
# episode = 99/100, score = 82

# %%
env.close()
